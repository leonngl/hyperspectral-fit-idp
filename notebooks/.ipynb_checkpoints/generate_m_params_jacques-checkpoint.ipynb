# %%
import os
import sys
from pathlib import Path
sys.path.insert(1, str(Path(os.getcwd()).parent / "src"))

# %%
import data_loader
from concentr_diffs_pathlength import *
from plotting import *
from mbll_functions import *
from utils import *
from mcs_function import *
from pathlib import Path
import config
import pickle
from scipy.optimize import least_squares
import pmcx
from tqdm.notebook import tqdm
import imageio

import matplotlib.pyplot as plt

# %%
config.gpuid
# Out:
# 6

# %%
config.m_params_path
# Out:
# PosixPath('/home/leon_ivan/nonlinear-fit/dataset/m_parameters.pickle')

# %% [markdown]
# In the Jacques model, diffuse reflectance is given as $$R_d = \exp(-A\delta \mu_a)$$, where A depends on the ratio of the absorption and scattering $N = \frac{\mu_s'}{\mu_a}$ coefficient, and is modelled as
# $$ A(N) = m_1 + m_2\exp(\frac{\ln(N)}{m_3}) $$
# and $\delta$ is $$\delta = (3\mu_a(\mu_s' + \mu_a))^{-\frac{1}{2}}$$
# A also depends on the refractive index. The $m_i$-parameters in paper and Jacque's website are based on a refractive index of 1.33. For the brain we expect 1.36 (gray matter) to 1.4 (blood vessels). To determine the $m_i$ for these indices, we run Monte Carlo Simulations with reasonable absorption/scattering coefficients and fit the $m_i$ to the obtained values for A.\
# For absorption/scattering coefficients we use literature values of gray matter and blood vessel tissue. Additionally, we use some very high values for $N$, as it was done on Jacque's website.

# %%
 # both inclusive
loader = data_loader.DataLoader(None, 450, 999)
# absorption spectra for HbO2, Hbb, oxCCO, redCCO, water and fat
mu_a_matrix = loader.absorption_coefs(
    use_diff_oxycco = False,
    use_water_and_fat = True
)

# %%
sample_wavelengths = np.arange(loader.wavelength_left_cut, loader.wavelength_right_cut, 25)
if sample_wavelengths[-1] != loader.wavelength_right_cut:
    sample_wavelengths = np.append(sample_wavelengths, loader.wavelength_right_cut)[1:]
print(sample_wavelengths)
# Out:
# [475 500 525 550 575 600 625 650 675 700 725 750 775 800 825 850 875 900
#  925 950 975 999]

# %%
g_gm = 0.85
refractive_idx_gm = 1.36
mu_a_gm = data_loader.DataLoader.mu_a_func_gray_matter(sample_wavelengths) / 10
mu_s_gm = data_loader.DataLoader.mu_s_red_func_gray_matter(sample_wavelengths) / 10 / (1 - g_gm)

# %%
g_bv = 0.935
refractive_idx_bv = 1.4
mu_a_bv = data_loader.DataLoader.mu_a_func_blood_vessel(sample_wavelengths) / 10
mu_s_bv = data_loader.DataLoader.mu_s_red_func_blood_vessel(sample_wavelengths) / 10 / (1 - g_bv)

# %%
# For refractive index of 1.38 compute the m-parameters based on combined blood and cortex values
g_combined = 0.8675
refractive_idx_combined = 1.38
mu_a_combined = np.concatenate((mu_a_gm, mu_a_bv))
mu_s_combined = np.concatenate((mu_s_gm * (1-g_gm) / (1-g_combined), mu_s_bv * (1-g_bv) / (1-g_combined)))

# %%
# Optionally append very high N values, as it was done on Jacques website
#mu_a_gm = np.append(mu_a_gm, np.repeat((1 - g_gm), 3))
#mu_s_gm = np.append(mu_s_gm, np.array([1e2, 1e3, 5e3]))
#mu_a_bv = np.append(mu_a_bv, np.repeat((1 - g_bv), 3))
#mu_s_bv = np.append(mu_s_bv, np.array([1e2, 1e3, 5e3]))
mu_a_combined = np.append(mu_a_combined, np.repeat((1 - g_combined), 3))
mu_s_combined = np.append(mu_s_combined, np.array([1e2, 1e3, 5e3]))

# %%
mcs_params_total = {
    refractive_idx_gm: (mu_a_gm, mu_s_gm, g_gm),
    refractive_idx_bv: (mu_a_bv, mu_s_bv, g_bv),
    refractive_idx_combined: (mu_a_combined, mu_s_combined, g_combined)
}

# %%
mu_a_combined.shape
# Out:
# (47,)

# %%
A_vals = dict()
dref_vals = dict()
m_params = dict()
N_vals = dict()

# empty log file
open(config.m_params_path.parent / "log.txt", "w").close()

# make sure to make this a separate array, don't create directly in cfg!
prop = np.array([[0,0,1,1],[0,0,1.2,1.5]])

vol = np.ones((100, 100, 120), dtype="uint8")

cfg = {
    "nphoton": 1e7,
    "maxdetphoton": 1e7,
    "vol": vol,
    "tstart":0,
    "tend":1e-8,
    "tstep":1e-8,
    "autopilot": 1,
    "gpuid": config.gpuid,
    "prop": prop,
    "bc": "ccrcca",#001000",
    "isspecular": 1,
    "srcdir": [0,0,1],
    "srctype": "planar",
    "srcpos": [0, 0, 0],
    "srcparam1": [100, 0, 0, 0], # 3D position of vertex, fourth coordinate is irrelevant
    "srcparam2": [0, 100, 0, 0],
    "issrcfrom0": 1,
    #"savedetflag": "dpx",
    "flog": str(config.m_params_path.parent) + "/log.txt",
    "isnormalized": 0,
    "issaveref": 1
}

# necessary to accumulate weights
cfg["vol"][:, :, 0] = 0

def A_residual(m_params, A_vals, N_vals):
    m1, m2, m3 = m_params
    return A_vals - (m1 + m2 * np.exp(np.log(N_vals)/m3))

for refractive_idx, (mu_a_tissue, mu_s_tissue, g_tissue) in mcs_params_total.items():
    A_vals[refractive_idx] = []
    N_vals[refractive_idx] = []
    dref_vals[refractive_idx] = []
    for mu_a, mu_s in zip(mu_a_tissue, mu_s_tissue):
        cfg["prop"][1, 0] = mu_a
        cfg["prop"][1, 1] = mu_s
        cfg["prop"][1, 2] = g_tissue
        cfg["prop"][1, 3] = refractive_idx
        res = pmcx.mcxlab(cfg)
        #mean_pl = pmcx.utils.meanpath(res["detp"])[0]
        mu_s_red = mu_s * (1 - g_tissue)
        delta = 1 / np.sqrt(3 * mu_a * (mu_a + mu_s_red))
        #A = mean_pl / delta
        dref = np.sum(res["dref"][:, :, 0, :]) / cfg["nphoton"]
        dref_vals[refractive_idx].append(dref)
        A = -np.log(dref) / (delta * mu_a)
        A_vals[refractive_idx].append(A)
        print(f"N: {mu_s_red / mu_a}    A:{A}")
        
    N_vals[refractive_idx] = mu_s_tissue * (1 - g_tissue) / mu_a_tissue
    # initial values by Jacques as initialization
    m = np.array([6.3744, 0.3568, 3.4739])
    ls_res = least_squares(A_residual, m, args=(A_vals[refractive_idx], N_vals[refractive_idx]))
    m_params[refractive_idx] = ls_res.x
# Out:
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 8.927875223024518    A:7.585595226184989
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 10.28116759252159    A:7.609913252313457
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 6.082674915385583    A:7.538684147572059
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.426661634000641    A:7.552884582285361
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.595959186715588    A:7.605686670210493
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 16.32886513593461    A:7.7178720945208275
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 51.503560618740245    A:8.070811380952927
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 67.12419276788549    A:8.16163314619462
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 73.20742224336952    A:8.19167932301846
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 82.20832348433974    A:8.235083309747449
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 71.00523886468912    A:8.183440461419298
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 55.774046526044806    A:8.102573721335162
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 48.09971137343804    A:8.047974548417914
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 42.20278782953805    A:8.003252350345688
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 33.895399192074706    A:7.934895552427147
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 27.460099348847372    A:7.8674460883361865
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 23.560995402203208    A:7.819355464058219
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 20.118956086099637    A:7.773799312670385
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 16.67460406245512    A:7.724014730555447
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 11.220347748435964    A:7.629059681833479
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 8.499450929376833    A:7.577118354698031
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 9.349885489546674    A:7.593254268146786
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.16118869169799313    A:10.519599968737039
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.2063453831786739    A:10.17434935715918
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.130151793000709    A:10.835362123457115
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.07904840082733158    A:11.585745192863644
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.0676339217052809    A:11.821167251037714
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.5890293274321872    A:8.856241846892967
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.328883425677449    A:7.893631989119286
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.312589085904125    A:7.816777935660215
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.8066360609108427    A:7.805836471607355
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 4.648210127002913    A:7.801512629967964
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 4.781898836449298    A:7.8034860332491025
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.948870077408776    A:7.800861598212021
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.763466165458927    A:7.804444462770468
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.5883524326646072    A:7.8107157300653105
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.035668556156352    A:7.832515654366313
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.6685193621782757    A:7.855927408992264
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.407281615849463    A:7.88224046519411
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.2334701373191677    A:7.904679569015981
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.1602200374585334    A:7.915219429119958
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.1742006111507792    A:7.916179555551238
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.295012359478575    A:7.897639301159529
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.555578980042256    A:7.865220959470427
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 8.92787522302452    A:7.733859947357916
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 10.28116759252159    A:7.762645834902152
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 6.082674915385583    A:7.675215444129992
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.426661634000641    A:7.676332185061459
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.595959186715588    A:7.724284678173992
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 16.32886513593461    A:7.882323512404439
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 51.503560618740245    A:8.276887181796562
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 67.12419276788549    A:8.377761949516751
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 73.20742224336952    A:8.41198571410643
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 82.20832348433974    A:8.458389843678928
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 71.00523886468912    A:8.400713080574173
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 55.774046526044806    A:8.306645617753114
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 48.09971137343804    A:8.25119605058289
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 42.20278782953805    A:8.20591880761939
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 33.895399192074706    A:8.123925490835715
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 27.460099348847372    A:8.0483759547265
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 23.560995402203208    A:7.996820622959155
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 20.118956086099637    A:7.946571820338135
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 16.67460406245512    A:7.888973537913607
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 11.220347748435964    A:7.787427627440357
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 8.499450929376833    A:7.724048557828674
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 9.349885489546674    A:7.741464768770576
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.16118869169799313    A:10.3311588779309
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.2063453831786739    A:9.981841590464791
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.130151793000709    A:10.636585262599075
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.07904840082733158    A:11.381825402244134
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.0676339217052809    A:11.623705669695182
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.5890293274321872    A:8.690305505105194
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.328883425677449    A:7.7531502887609
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.312589085904125    A:7.678860548968101
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.806636060910843    A:7.6628115993546055
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 4.648210127002913    A:7.658364462338574
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 4.781898836449298    A:7.661166975683365
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.948870077408776    A:7.663188793978041
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.763466165458927    A:7.664118342771221
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.5883524326646072    A:7.669559551306319
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.035668556156352    A:7.690453261987797
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.6685193621782757    A:7.716745422996293
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.407281615849463    A:7.743534988067695
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.2334701373191677    A:7.765293434875369
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.1602200374585334    A:7.777351327062696
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.1742006111507797    A:7.773260311389644
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.295012359478575    A:7.7578004323746805
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.555578980042256    A:7.729062634896179
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 100.0    A:8.537390100824735
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-07
# tend: 5e-07
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1

# %%
mu_a_gm.shape

# %% [markdown]
# Compare diffuse reflectance computed during MCS with dref computed here...

# %% [markdown]
# Store the parameters...

# %%
with open(config.m_params_path, "wb") as f:
    pickle.dump((m_params, A_vals, N_vals, dref_vals), f)

# %% [markdown]
# Load the parameters...

# %%
with open(config.m_params_path, "rb") as f:
    m_params, A_vals, N_vals, dref_vals = pickle.load(f)

# %%
refractive_idxs = [1.36, 1.38, 1.4]

fig, axs = plt.subplots(len(refractive_idxs), 1)

for i, (refractive_idx, (mu_a_tissue, mu_s_tissue, g_tissue)) in enumerate(mcs_params_total.items()):
    m1, m2, m3 = m_params[refractive_idx]
    N_vals = mu_s_tissue * (1 - g_tissue) / mu_a_tissue
    N_vals_interp = np.linspace(np.min(N_vals), np.max(N_vals), 100)
    axs[i].plot(N_vals_interp, m1 + m2*np.exp(np.log(N_vals_interp)/m3))
    axs[i].scatter(N_vals, A_vals[refractive_idx])
    axs[i].set_xscale("log")
    axs[i].set_title(f"{refractive_idx}")
    axs[i].text(0.01, 0.5, f"m1: {m1}\nm2: {m2}\nm3: {m3}", transform=axs[i].transAxes)

plt.show()
