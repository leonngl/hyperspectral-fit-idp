# %%
import os
import sys
from pathlib import Path
sys.path.insert(1, str(Path(os.getcwd()).parent / "src"))

# %%
import data_loader
from concentr_diffs_pathlength import *
from plotting import *
from mbll_functions import *
from utils import *
from mcs_function import *
from pathlib import Path
import config
import pickle
from scipy.optimize import least_squares
import pmcx
from tqdm.notebook import tqdm
import imageio

import matplotlib.pyplot as plt

# %%
pmcx.gpuinfo()
# Out:
# [{'name': 'Quadro RTX 8000',
#   'id': 1,
#   'devcount': 8,
#   'major': 7,
#   'minor': 5,
#   'globalmem': 50953846784,
#   'constmem': 65536,
#   'sharedmem': 49152,
#   'regcount': 65536,
#   'clock': 1770000,
#   'sm': 72,
#   'core': 4608,
#   'autoblock': 64,
#   'autothread': 147456,
#   'maxgate': 0},
#  {'name': 'Quadro RTX 8000',
#   'id': 2,
#   'devcount': 8,
#   'major': 7,
#   'minor': 5,
#   'globalmem': 50953846784,
#   'constmem': 65536,
#   'sharedmem': 49152,
#   'regcount': 65536,
#   'clock': 1770000,
#   'sm': 72,
#   'core': 4608,
#   'autoblock': 64,
#   'autothread': 147456,
#   'maxgate': 0},
#  {'name': 'Quadro RTX 8000',
#   'id': 3,
#   'devcount': 8,
#   'major': 7,
#   'minor': 5,
#   'globalmem': 50953846784,
#   'constmem': 65536,
#   'sharedmem': 49152,
#   'regcount': 65536,
#   'clock': 1770000,
#   'sm': 72,
#   'core': 4608,
#   'autoblock': 64,
#   'autothread': 147456,
#   'maxgate': 0},
#  {'name': 'Quadro RTX 8000',
#   'id': 4,
#   'devcount': 8,
#   'major': 7,
#   'minor': 5,
#   'globalmem': 50953846784,
#   'constmem': 65536,
#   'sharedmem': 49152,
#   'regcount': 65536,
#   'clock': 1770000,
#   'sm': 72,
#   'core': 4608,
#   'autoblock': 64,
#   'autothread': 147456,
#   'maxgate': 0},
#  {'name': 'Quadro RTX 8000',
#   'id': 5,
#   'devcount': 8,
#   'major': 7,
#   'minor': 5,
#   'globalmem': 50953846784,
#   'constmem': 65536,
#   'sharedmem': 49152,
#   'regcount': 65536,
#   'clock': 1770000,
#   'sm': 72,
#   'core': 4608,
#   'autoblock': 64,
#   'autothread': 147456,
#   'maxgate': 0},
#  {'name': 'Quadro RTX 6000',
#   'id': 6,
#   'devcount': 8,
#   'major': 7,
#   'minor': 5,
#   'globalmem': 25388515328,
#   'constmem': 65536,
#   'sharedmem': 49152,
#   'regcount': 65536,
#   'clock': 1770000,
#   'sm': 72,
#   'core': 4608,
#   'autoblock': 64,
#   'autothread': 147456,
#   'maxgate': 0},
#  {'name': 'Quadro RTX 8000',
#   'id': 7,
#   'devcount': 8,
#   'major': 7,
#   'minor': 5,
#   'globalmem': 50953846784,
#   'constmem': 65536,
#   'sharedmem': 49152,
#   'regcount': 65536,
#   'clock': 1770000,
#   'sm': 72,
#   'core': 4608,
#   'autoblock': 64,
#   'autothread': 147456,
#   'maxgate': 0},
#  {'name': 'Quadro P5000',
#   'id': 8,
#   'devcount': 8,
#   'major': 6,
#   'minor': 1,
#   'globalmem': 17063280640,
#   'constmem': 65536,
#   'sharedmem': 49152,
#   'regcount': 65536,
#   'clock': 1733500,
#   'sm': 20,
#   'core': 2560,
#   'autoblock': 64,
#   'autothread': 40960,
#   'maxgate': 0}]

# %%
gpuid = 6

# %%
config.m_params_path
# Out:
# PosixPath('/home/leon_ivan/nonlinear-fit/dataset/m_parameters.pickle')

# %% [markdown]
# In the Jacques model, diffuse reflectance is given as $$R_d = \exp(-A\delta \mu_a)$$, where A depends on the ratio of the absorption and scattering $N = \frac{\mu_s'}{\mu_a}$ coefficient, and is modelled as
# $$ A(N) = m_1 + m_2\exp(\frac{\ln(N)}{m_3}) $$
# and $\delta$ is $$\delta = (3\mu_a(\mu_s' + \mu_a))^{-\frac{1}{2}}$$
# A also depends on the refractive index. The $m_i$-parameters in paper and Jacque's website are based on a refractive index of 1.33. For the brain we expect 1.36 (gray matter) to 1.4 (blood vessels). To determine the $m_i$ for these indices, we run Monte Carlo Simulations with reasonable absorption/scattering coefficients and fit the $m_i$ to the obtained values for A.\
# For absorption/scattering coefficients we use literature values of gray matter and blood vessel tissue. Additionally, we use some very high values for $N$, as it was done on Jacque's website.

# %%
 # both inclusive
loader = data_loader.DataLoader(None, 450, 999)
# absorption spectra for HbO2, Hbb, oxCCO, redCCO, water and fat
mu_a_matrix = loader.absorption_coefs(
    use_diff_oxycco = False,
    use_water_and_fat = True
)

# %%
sample_wavelengths = np.arange(loader.wavelength_left_cut, loader.wavelength_right_cut, 25)
if sample_wavelengths[-1] != loader.wavelength_right_cut:
    sample_wavelengths = np.append(sample_wavelengths, loader.wavelength_right_cut)[1:]
print(sample_wavelengths)
# Out:
# [475 500 525 550 575 600 625 650 675 700 725 750 775 800 825 850 875 900
#  925 950 975 999]

# %%
g_gm = 0.85
refractive_idx_gm = 1.36
mu_a_vector_gm = mu_a_matrix @ loader.params_ref_gray_matter[:6] / 10 # MMX takes mu in 1/mm
mu_a_func_gm = lambda wl: mu_a_vector_gm[np.array(wl).astype(int) - loader.wavelength_left_cut]
mu_s_red_func_gm = lambda wl: loader.params_ref_gray_matter[-2] * np.power((wl/500), -loader.params_ref_gray_matter[-1]) / 10
mu_s_func_gm = lambda wl: mu_s_red_func_gm(wl) / (1 - g_gm)

mu_a_gm = mu_a_func_gm(sample_wavelengths)
mu_s_gm = mu_s_func_gm(sample_wavelengths)

# %%
g_bv = 0.935
refractive_idx_bv = 1.4
mu_a_vector_bv = mu_a_matrix @ loader.params_ref_blood_vessel[:6] / 10 # MMX takes mu_a in 1/mm
mu_a_func_bv = lambda wl: mu_a_vector_bv[np.array(wl).astype(int) - loader.wavelength_left_cut]
mu_s_red_func_bv = lambda wl: loader.params_ref_blood_vessel[-2] * np.power((wl/500), -loader.params_ref_blood_vessel[-1]) / 10
mu_s_func_bv = lambda wl: mu_s_red_func_bv(wl) / (1 - g_bv)

mu_a_bv = mu_a_func_bv(sample_wavelengths)
mu_s_bv = mu_s_func_bv(sample_wavelengths)

# %%
# For refractive index of 1.38 compute the m-parameters based on combined blood and cortex values
g_combined = 0.9
refractive_idx_combined = 1.38
mu_a_combined = np.concatenate((mu_a_gm, mu_a_bv))
mu_s_combined = np.concatenate((mu_s_red_func_gm(sample_wavelengths) / (1-g_combined), mu_s_red_func_bv(sample_wavelengths) / (1-g_combined)))

# %%
# Optionally append very high N values, as it was done on Jacques website
#mu_a_gm = np.append(mu_a_gm, np.repeat((1 - g_gm), 3))
#mu_s_gm = np.append(mu_s_gm, np.array([1e2, 1e3, 5e3]))
#mu_a_bv = np.append(mu_a_bv, np.repeat((1 - g_bv), 3))
#mu_s_bv = np.append(mu_s_bv, np.array([1e2, 1e3, 5e3]))
mu_a_combined = np.append(mu_a_combined, np.repeat((1 - g_combined), 3))
mu_s_combined = np.append(mu_s_combined, np.array([1e2, 1e3, 5e3]))

# %%
mcs_params_total = {
    refractive_idx_gm: (mu_a_gm, mu_s_gm, g_gm),
    refractive_idx_bv: (mu_a_bv, mu_s_bv, g_bv),
    refractive_idx_combined: (mu_a_combined, mu_s_combined, g_combined)
}

# %%
mu_a_combined.shape
# Out:
# (44,)

# %%
mu_a_gm.shape
# Out:
# (22,)

# %%
A_vals = dict()
dref_vals = dict()
m_params = dict()
N_vals = dict()

# empty log file
open(config.m_params_path.parent / "log.txt", "w").close()

# make sure to make this a separate array, don't create directly in cfg!
prop_mcs = np.array([[0,0,1,1],[0,0,1.2,1.5]])

vol = np.ones((100, 100, 120), dtype="uint8")

cfg = {
    "nphoton": 1e7,
    "maxdetphoton": 1e7,
    "vol": vol,
    "tstart":0,
    "tend":5e-9,
    "tstep":5e-9,
    "autopilot": 1,
    "gpuid": gpuid,
    "prop": prop_mcs,
    "bc": "ccrcca",#001000",
    "isspecular": 1,
    "srcdir": [0,0,1],
    "srctype": "planar",
    "srcpos": [0, 0, 0],
    "srcparam1": [100, 0, 0, 0], # 3D position of vertex, fourth coordinate is irrelevant
    "srcparam2": [0, 100, 0, 0],
    "issrcfrom0": 1,
    #"savedetflag": "dpx",
    "flog": str(config.m_params_path.parent) + "/log.txt",
    "isnormalized": 0,
    "issaveref": 1
}

# necessary to accumulate weights
cfg["vol"][:, :, 0] = 0

def A_residual(m_params, A_vals, N_vals):
    m1, m2, m3 = m_params
    return A_vals - (m1 + m2 * np.exp(np.log(N_vals)/m3))

for refractive_idx, (mu_a_tissue, mu_s_tissue, g_tissue) in mcs_params_total.items():
    A_vals[refractive_idx] = []
    N_vals[refractive_idx] = []
    dref_vals[refractive_idx] = []
    for mu_a, mu_s in zip(mu_a_tissue, mu_s_tissue):
        cfg["prop"][1, 0] = mu_a
        cfg["prop"][1, 1] = mu_s
        cfg["prop"][1, 2] = g_tissue
        cfg["prop"][1, 3] = refractive_idx
        res = pmcx.mcxlab(cfg)
        #mean_pl = pmcx.utils.meanpath(res["detp"])[0]
        mu_s_red = mu_s * (1 - g_tissue)
        delta = 1 / np.sqrt(3 * mu_a * (mu_a + mu_s_red))
        #A = mean_pl / delta
        dref = np.sum(res["dref"][:, :, 0, :]) / cfg["nphoton"]
        dref_vals[refractive_idx].append(dref)
        A = -np.log(dref) / (delta * mu_a)
        A_vals[refractive_idx].append(A)
        print(f"N: {mu_s_red / mu_a}    A:{A}")
        
    N_vals[refractive_idx] = mu_s_tissue * (1 - g_tissue) / mu_a_tissue
    # initial values by Jacques as initialization
    m = np.array([6.3744, 0.3568, 3.4739])
    ls_res = least_squares(A_residual, m, args=(A_vals[refractive_idx], N_vals[refractive_idx]))
    m_params[refractive_idx] = ls_res.x
# Out:
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# =============================   GPU Information  ================================
# Device 1 of 8:		Quadro RTX 8000
# Compute Capability:	7.5
# Global Memory:		50953846784 B
# Constant Memory:	65536 B
# Shared Memory:		49152 B
# Registers:		65536
# Clock Speed:		1.77 GHz
# Number of SMs:		72
# Number of Cores:	4608
# Auto-thread:		147456
# Auto-block:		64
# =============================   GPU Information  ================================
# Device 2 of 8:		Quadro RTX 8000
# Compute Capability:	7.5
# Global Memory:		50953846784 B
# Constant Memory:	65536 B
# Shared Memory:		49152 B
# Registers:		65536
# Clock Speed:		1.77 GHz
# Number of SMs:		72
# Number of Cores:	4608
# Auto-thread:		147456
# Auto-block:		64
# =============================   GPU Information  ================================
# Device 3 of 8:		Quadro RTX 8000
# Compute Capability:	7.5
# Global Memory:		50953846784 B
# Constant Memory:	65536 B
# Shared Memory:		49152 B
# Registers:		65536
# Clock Speed:		1.77 GHz
# Number of SMs:		72
# Number of Cores:	4608
# Auto-thread:		147456
# N: 8.927875223024518    A:7.5878491163060655
# nphoton: 1e+07
# ck:		64
# =============================   GPU Information  ================================
# Device 4 of 8:		Quadro RTX 8000
# Compute Capability:	7.5
# Global Memory:		50953846784 B
# Constant Memory:	65536 B
# Shared Memory:		49152 B
# Registers:		65536
# Clock Speed:		1.77 GHz
# Number of SMs:		72
# Number of Cores:	4608
# Auto-thread:		147456
# Auto-block:		64
# =============================   GPU Information  ================================
# Device 5 of 8:		Quadro RTX 8000
# Compute Capability:	7.5
# Global Memory:		50953846784 B
# Constant Memory:	65536 B
# Shared Memory:		49152 B
# Registers:		65536
# Clock Speed:		1.77 GHz
# Number of SMs:		72
# Number of Cores:	4608
# Auto-thread:		147456
# Auto-block:		64
# =============================   GPU Information  ================================
# Device 6 of 8:		Quadro RTX 6000
# Compute Capability:	7.5
# Global Memory:		25388515328 B
# Constant Memory:	65536 B
# Shared Memory:		49152 B
# Registers:		65536
# Clock Speed:		1.77 GHz
# Number of SMs:		72
# Number of Cores:	4608
# Auto-thread:		147456
# Auto-block:		64
# =============================   GPU Information  ================================
# Device 7 of 8:		Quadro RTX 8000
# Compute Capability:	7.5
# Global Memory:		50953846784 B
# Constant Memory:	65536 B
# Shared Memory:		49152 B
# Registers:		65536
# Clock Speed:		1.77 GHz
# Number of SMs:		72
# Number of Cores:	4608
# Auto-thread:		147456
# Auto-block:		64
# =============================   GPU Information  ================================
# Device 8 of 8:		Quadro P5000
# Compute Capability:	6.1
# Global Memory:		17063280640 B
# Constant Memory:	65536 B
# Shared Memory:		49152 B
# Registers:		65536
# Clock Speed:		1.73 GHz
# Number of SMs:		20
# Number of Cores:	2560
# Auto-thread:		40960
# Auto-block:		64
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 10.28116759252159    A:7.613323537644078
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 6.082674915385583    A:7.539635771666616
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.426661634000641    A:7.555425130391109
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.595959186715588    A:7.610008580340664
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 16.32886513593461    A:7.718733813407385
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 51.503560618740245    A:8.071827293759748
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 67.12419276788549    A:8.164587449342246
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 73.20742224336952    A:8.194409118733427
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 82.20832348433974    A:8.23843890603786
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 71.00523886468912    A:8.183510993752723
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 55.774046526044806    A:8.099883656486554
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 48.09971137343804    A:8.046507151802865
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 42.20278782953805    A:8.004167563634722
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 33.895399192074706    A:7.932728183924134
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 27.460099348847372    A:7.864627705166032
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 23.560995402203208    A:7.817793147004249
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 20.118956086099637    A:7.773564692842326
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 16.67460406245512    A:7.722951048661957
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 11.220347748435964    A:7.627314919824879
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 8.499450929376833    A:7.578264541849466
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 9.349885489546674    A:7.593268418081205
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.16118869169799313    A:10.520942746806844
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.2063453831786739    A:10.170448083992865
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.130151793000709    A:10.830760869295672
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.07904840082733158    A:11.589336601386352
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.0676339217052809    A:11.821451272068089
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.5890293274321872    A:8.853991473546351
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.328883425677449    A:7.889966813228294
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.312589085904125    A:7.821114571836866
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.8066360609108427    A:7.809054053118616
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 4.648210127002913    A:7.804425308029252
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 4.781898836449298    A:7.8029334615658685
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.948870077408776    A:7.802230320558374
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.763466165458927    A:7.808063223439118
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.5883524326646072    A:7.809408984919056
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.035668556156352    A:7.829518757121895
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.6685193621782757    A:7.855330649619097
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.407281615849463    A:7.8833783324911115
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.2334701373191677    A:7.9044307907720555
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.1602200374585334    A:7.914831477758363
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.1742006111507792    A:7.9123069029317
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.295012359478575    A:7.894994895806726
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.555578980042256    A:7.866242244382875
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 8.927875223024518    A:7.733431650322418
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 10.28116759252159    A:7.765616908051662
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 6.082674915385583    A:7.682899943417022
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.426661634000641    A:7.687659287425276
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.595959186715588    A:7.737786114566981
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 16.32886513593461    A:7.884480100515366
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 51.503560618740245    A:8.275894576648147
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 67.12419276788549    A:8.379999491567064
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 73.20742224336952    A:8.41077177545806
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 82.20832348433974    A:8.460636630315403
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 71.00523886468912    A:8.40252097742409
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 55.774046526044806    A:8.309368777405362
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 48.09971137343804    A:8.254815870362286
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 42.20278782953805    A:8.204042859675539
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 33.895399192074706    A:8.124494769846104
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 27.460099348847372    A:8.052947777313811
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 23.560995402203208    A:8.0026435071291
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 20.118956086099637    A:7.9482174505148615
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 16.67460406245512    A:7.893383881753253
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 11.220347748435964    A:7.7890991506395135
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 8.499450929376833    A:7.7296524618127584
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 9.349885489546674    A:7.746831647828036
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.16118869169799313    A:10.388954862568944
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.2063453831786739    A:10.043460639307645
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.130151793000709    A:10.695122175984855
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.07904840082733158    A:11.446778326729776
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.0676339217052809    A:11.689273712582377
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 0.5890293274321872    A:8.728439086708924
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.328883425677449    A:7.768057801987678
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.3125890859041247    A:7.692940395106374
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.8066360609108427    A:7.676677048659779
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 4.648210127002913    A:7.668525016041077
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 4.781898836449298    A:7.670096710670375
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.948870077408776    A:7.6742673163921395
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.763466165458927    A:7.677380189629436
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.5883524326646072    A:7.682004646429788
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 3.035668556156352    A:7.7038005163866865
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.6685193621782752    A:7.733157839663119
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.407281615849463    A:7.758452226790451
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.2334701373191677    A:7.781500452076894
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.1602200374585334    A:7.795027943016485
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.1742006111507792    A:7.791817397216092
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.295012359478575    A:7.774232237045078
# nphoton: 1e+07
# tstart: 0
# tstep: 5e-09
# tend: 5e-09
# maxdetphoton: 1e+07
# isnormalized: 0
# issrcfrom0: 1
# autopilot: 1
# issaveref: 1
# isspecular: 1
# N: 2.555578980042256    A:7.7415160350286545

# %% [markdown]
# Compare diffuse reflectance computed during MCS with dref computed here...

# %%
gray_matter_mcs_data = np.loadtxt(config.pl_dir / "gray_matter_mcs.txt")
assert(np.allclose(gray_matter_mcs_data[:, 0], sample_wavelengths))

plt.plot(gray_matter_mcs_data[:, 0], gray_matter_mcs_data[:, 3] - dref_vals[1.36][0])
# attenuation difference caused by dref-difference - proportional to PL difference
# print(-np.log(gray_matter_mcs_data[:, 3]/dref_vals[1.36][0]))

# attenuation ratio, equal to PL ration
# print(-np.log(gray_matter_mcs_data[:, 3])/-np.log(dref_vals[1.36][0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 gray_matter_mcs_data = np.loadtxt(config.pl_dir / "gray_matter_mcs.txt")
# ----> 2 assert(np.allclose(gray_matter_mcs_data[:, 0], sample_wavelengths))
#       4 plt.plot(gray_matter_mcs_data[:, 0], gray_matter_mcs_data[:, 3] - dref_vals[1.36][0])
#       5 # attenuation difference caused by dref-difference - proportional to PL difference
#       6 # print(-np.log(gray_matter_mcs_data[:, 3]/dref_vals[1.36][0]))
#       7
#       8 # attenuation ratio, equal to PL ration
#       9 # print(-np.log(gray_matter_mcs_data[:, 3])/-np.log(dref_vals[1.36][0]))
#
# File <__array_function__ internals>:200, in allclose(*args, **kwargs)
#
# File ~/miniconda3/envs/idp_leon/lib/python3.11/site-packages/numpy/core/numeric.py:2270, in allclose(a, b, rtol, atol, equal_nan)
#    2199 @array_function_dispatch(_allclose_dispatcher)
#    2200 def allclose(a, b, rtol=1.e-5, atol=1.e-8, equal_nan=False):
#    2201     """
#    2202     Returns True if two arrays are element-wise equal within a tolerance.
#    2203
#    (...)
#    2268
#    2269     """
# -> 2270     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2271     return bool(res)
#
# File <__array_function__ internals>:200, in isclose(*args, **kwargs)
#
# File ~/miniconda3/envs/idp_leon/lib/python3.11/site-packages/numpy/core/numeric.py:2380, in isclose(a, b, rtol, atol, equal_nan)
#    2378 yfin = isfinite(y)
#    2379 if all(xfin) and all(yfin):
# -> 2380     return within_tol(x, y, atol, rtol)
#    2381 else:
#    2382     finite = xfin & yfin
#
# File ~/miniconda3/envs/idp_leon/lib/python3.11/site-packages/numpy/core/numeric.py:2361, in isclose.<locals>.within_tol(x, y, atol, rtol)
#    2359 def within_tol(x, y, atol, rtol):
#    2360     with errstate(invalid='ignore'), _no_nep50_warning():
# -> 2361         return less_equal(abs(x-y), atol + rtol * abs(y))
#
# ValueError: operands could not be broadcast together with shapes (23,) (22,)

# %% [markdown]
# Store the parameters...

# %%
with open(config.m_params_path, "wb") as f:
    pickle.dump((m_params, A_vals, N_vals, dref_vals), f)

# %% [markdown]
# Load the parameters...

# %%
with open(config.m_params_path, "rb") as f:
    m_params, A_vals, N_vals, dref_vals = pickle.load(f)

# %%
refractive_idxs = [1.36, 1.38, 1.4]

fig, axs = plt.subplots(len(refractive_idxs), 1)

for i, (refractive_idx, (mu_a_tissue, mu_s_tissue, g_tissue)) in enumerate(mcs_params_total.items()):
    m1, m2, m3 = m_params[refractive_idx]
    N_vals = mu_s_tissue * (1 - g_tissue) / mu_a_tissue
    N_vals_interp = np.linspace(np.min(N_vals) / 2, np.max(N_vals), 100)
    axs[i].plot(N_vals_interp, m1 + m2*np.exp(np.log(N_vals_interp)/m3))
    axs[i].scatter(N_vals, A_vals[refractive_idx])
    axs[i].set_xscale("log")
    axs[i].set_title(f"{refractive_idx}")
    axs[i].text(0.01, 0.5, f"m1: {m1}\nm2: {m2}\nm3: {m3}", transform=axs[i].transAxes)

plt.show()
